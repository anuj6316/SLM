# %%
# !tree ..
# Out:
# ..
# ├── app.py
# ├── bfs_output.md
# ├── cleaned_output.md
# ├── config.py
# ├── config.yml
# ├── crawl_output.md
# ├── docs
# │   └── raw_text_extraction.md
# ├── experiments
# │   ├── distilable_test.py
# │   └── notebook1.ipynb
# ├── main.py
# ├── output.md
# ├── pipeline
# ├── prompts
# │   ├── __pycache__
# │   │   ├── question_generation.cpython-310.pyc
# │   │   └── system_prompt.cpython-310.pyc
# │   ├── question_generation.py
# │   └── system_prompt.py
# ├── __pycache__
# │   ├── config.cpython-310.pyc
# │   ├── main.cpython-310.pyc
# │   └── utils.cpython-310.pyc
# ├── q&a_generator.py
# ├── steps
# │   └── raw_data_extraction.py
# └── utils.py
#
# 8 directories, 21 files

# %%
import sys
import os

# Add the parent folder (project root) to sys.path
sys.path.append(os.path.abspath(".."))

# Now import works
from qa_generator import ProcessMarkdownQAPairs
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 8
#       5 sys.path.append(os.path.abspath(".."))
#       7 # Now import works
# ----> 8 from qa_generator import ProcessMarkdownQAPairs
#
# File ~/Desktop/SLM/unstructured_data/qa_generator.py:1
# ----> 1 from langchain_text_splitters import RecursiveCharacterTextSplitter
#       2 from langchain_groq import ChatGroq
#       3 from langchain_core.prompts import PromptTemplate
#
# ModuleNotFoundError: No module named 'langchain_text_splitters'
